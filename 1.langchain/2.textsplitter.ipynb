# %% [markdown]
# # text splitters

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("certificates.pdf")
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Certificates  \n1.  Ethical  Hacking  :'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='2.  Supervised  machine  learning  \n  3.  Data  processing  and  manipulation'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content="4.  Al  Automation  :  Build  LLM  Apps  &  Al-Agents  with  n8n  &  API's"),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='5.  docker'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='6.  Azure  ai  fundamentals'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='')]

# %% [markdown]
# ## how to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size =500,chunk_overlap=50)
final_documents = text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Certificates  \n1.  Ethical  Hacking  :'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='2.  Supervised  machine  learning  \n  3.  Data  processing  and  manipulation'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content="4.  Al  Automation  :  Build  LLM  Apps  &  Al-Agents  with  n8n  &  API's"),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='5.  docker'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='6.  Azure  ai  fundamentals')]

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Certificates
# 1.  Ethical  Hacking  :' metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}
# page_content='2.  Supervised  machine  learning
#   3.  Data  processing  and  manipulation' metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'certificates', 'source': 'certificates.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Good morning, everyone.\nLife often presents us with the same circumstances, but it's our perspective that determines the outcome. Think about three common items: a potato, an egg, and a coffee bean. All are subjected to the same boiling water, an intense challenge or adversity.\nThe potato starts off strong and hard, but the boiling water makes it soft and weak. It loses its form and substance.\nThe egg is fragile on the outside, but inside, the liquid interior hardens under the pressure and heat. It changes internally, becoming rigid and unyielding.\nBut the coffee bean is unique. When exposed to the boiling water, it changes the water itself, creating a rich, new brew.")]

# %%
speech = " "
with open("Speech.txt") as f:
    speech = f.read()


text_splitter = RecursiveCharacterTextSplitter(chunk_size =500,chunk_overlap=50)
text = text_splitter.create_documents([speech])
print(text)
# Out:
# [Document(metadata={}, page_content="Good morning, everyone.\nLife often presents us with the same circumstances, but it's our perspective that determines the outcome. Think about three common items: a potato, an egg, and a coffee bean. All are subjected to the same boiling water, an intense challenge or adversity.\nThe potato starts off strong and hard, but the boiling water makes it soft and weak. It loses its form and substance."), Document(metadata={}, page_content='The egg is fragile on the outside, but inside, the liquid interior hardens under the pressure and heat. It changes internally, becoming rigid and unyielding.\nBut the coffee bean is unique. When exposed to the boiling water, it changes the water itself, creating a rich, new brew.')]

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Good morning, everyone.\nLife often presents us with the same circumstances, but it's our perspective that determines the outcome. Think about three common items: a potato, an egg, and a coffee bean. All are subjected to the same boiling water, an intense challenge or adversity.\nThe potato starts off strong and hard, but the boiling water makes it soft and weak. It loses its form and substance.\nThe egg is fragile on the outside, but inside, the liquid interior hardens under the pressure and heat. It changes internally, becoming rigid and unyielding.\nBut the coffee bean is unique. When exposed to the boiling water, it changes the water itself, creating a rich, new brew.")]

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(separator="\n\n", chunk_size=100,chunk_overlap=20)
text_splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Good morning, everyone.\nLife often presents us with the same circumstances, but it's our perspective that determines the outcome. Think about three common items: a potato, an egg, and a coffee bean. All are subjected to the same boiling water, an intense challenge or adversity.\nThe potato starts off strong and hard, but the boiling water makes it soft and weak. It loses its form and substance.\nThe egg is fragile on the outside, but inside, the liquid interior hardens under the pressure and heat. It changes internally, becoming rigid and unyielding.\nBut the coffee bean is unique. When exposed to the boiling water, it changes the water itself, creating a rich, new brew.")]
